# %%
import datetime
import pandas as pd

# %%
data = pd.read_table('data/erum.txt.dat',sep=" ", header=None).drop(2,axis=1)
data.columns = ['time','value']
print(data.shape)
# Out:
# (20182, 2)

# %%
for i in data['time'][:1000]:
    print(datetime.datetime.fromtimestamp(int(i)).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# 1970-01-29 12:07:02
# 1970-01-29 12:07:02
# 1970-01-29 12:07:02
# 1970-01-29 12:07:02
# 1970-01-29 12:07:02
# 1970-01-29 12:07:02
# 1970-01-29 12:07:02
# 1970-01-29 12:07:02
# 1970-01-29 12:07:02
# 1970-01-29 12:07:02
# 1970-01-29 12:07:02
# 1970-01-29 12:07:02
# 1970-01-29 12:07:02
# 1970-01-29 12:07:02
# 1970-01-29 12:07:02
# 1970-01-29 12:07:02
# 1970-01-29 12:07:02
# 1970-01-29 12:07:02
# 1970-01-29 12:07:02
# 1970-01-29 12:07:02
# 1970-01-29 12:07:02
# 1970-01-29 12:07:02
# 1970-01-29 12:07:02
# 1970-01-29 12:07:02
# 1970-01-29 12:07:02
# 1970-01-29 12:07:02
# 1970-01-29 12:07:02
# 1970-01-29 12:07:02
# 1970-01-29 12:07:02
# 1970-01-29 12:07:02
# 1970-01-29 12:07:02
# 1970-01-29 12:07:02
# 1970-01-29 12:07:02
# 1970-01-29 12:07:02
# 1970-01-29 12:07:02
# 1970-01-29 12:07:02
# 1970-01-29 12:07:02
# 1970-01-29 12:07:02
# 1970-01-29 12:07:02
# 1970-01-29 12:07:02
# 1970-01-29 12:07:02
# 1970-01-29 12:07:02
# 1970-01-29 12:07:02
# 1970-01-29 12:07:02
# 1970-01-29 12:07:02
# ...

# %%
i
# Out:
# 2455622.54983
